# %%
import requests
api_key=input("enter api key")
city=input("Enter city name:  ")
url=f"http://api.weatherapi.com/v1/current.json?key={api_key}&q={city}"#{}-customization
response=requests.get(url)
data=response.json()
print(data)
if data["error"]["code"]==1006:
  print("No location found matching parameter")
elif data["error"]["code"]==2008:
  print("API key proiveded is invalid")
else:
  print("City:",data["location"]["name"])
  print("State:",data["location"]["region"])
  print("current Condition:",data["current"]["condition"]["text"])
  print("Country:",data["location"]["country"])
  print("Temperature:",data["current"]["temp_c"])
  print("Wind Speed:",data["current"]["wind_mph"])
  print("Wind Direction :",data["current"]["wind_dir"])
  print("Humidity:",data["current"]["humidity"])
  print("feels:",data["current"]["feelslike_c"])
# Out:
# enter api keyfbbeufbef
# Enter city name:  eluru
# {'error': {'code': 2008, 'message': 'API key has been disabled.'}}
# API key proiveded is invalid

# %%
type(data)
dict
# Out:
# dict

# %%
#city name
#state region
#country country
#current condition
#temperature degree celsius temp_c
#wind speed(mph) wind_mph
#humidity humidity
#feels feels_like_c
print("City:",data["location"]["name"])
print("State:",data["location"]["region"])
print("current Condition:",data["current"]["condition"]["text"])
print("Country:",data["location"]["country"])
print("Temperature:",data["current"]["temp_c"])
print("Wind Speed:",data["current"]["wind_mph"])
print("Wind Direction :",data["current"]["wind_dir"])
print("Humidity:",data["current"]["humidity"])
print("feels:",data["current"]["feelslike_c"])
# Out:
# City: Nidadavole
# State: Andhra Pradesh
# current Condition: Sunny
# Country: India
# Temperature: 34.2
# Wind Speed: 4.9
# Wind Direction : ESE
# Humidity: 31
# feels: 34.5

# %%
import requests
api_key='cc96f18beaa343bca6a53605242802'
city=input("Enter City name:")
url=f"http://api.weatherapi.com/v1/current.json?key={api_key}&q={city}"#{} - customization
response=requests.get(url)
data=response.json()
print(data)
if response.status_code==200:
  print("City:",data["location"]["name"])
  print("State:",data["location"]["region"])
  print("Current Condition:",data["current"]["condition"]["text"])
  print("Country:",data["location"]["country"])
  print("Temperature:",data["current"]["temp_c"])
  print("Wind Speed:",data["current"]["wind_mph"])
  print("Wind Direction:",data["current"]["wind_dir"])
  print("Humidity:",data["current"]["humidity"])
  print("feels:",data["current"]["feelslike_c"])
else:
  print(data['error']['message'])
# Out:
# Enter City name:nidadavole
# {'location': {'name': 'Nidadavole', 'region': 'Andhra Pradesh', 'country': 'India', 'lat': 16.92, 'lon': 81.67, 'tz_id': 'Asia/Kolkata', 'localtime_epoch': 1709102120, 'localtime': '2024-02-28 12:05'}, 'current': {'last_updated_epoch': 1709101800, 'last_updated': '2024-02-28 12:00', 'temp_c': 36.0, 'temp_f': 96.8, 'is_day': 1, 'condition': {'text': 'Sunny', 'icon': '//cdn.weatherapi.com/weather/64x64/day/113.png', 'code': 1000}, 'wind_mph': 4.0, 'wind_kph': 6.5, 'wind_degree': 99, 'wind_dir': 'E', 'pressure_mb': 1011.0, 'pressure_in': 29.87, 'precip_mm': 0.0, 'precip_in': 0.0, 'humidity': 25, 'cloud': 9, 'feelslike_c': 35.5, 'feelslike_f': 96.0, 'vis_km': 10.0, 'vis_miles': 6.0, 'uv': 9.0, 'gust_mph': 4.6, 'gust_kph': 7.5}}
# City: Nidadavole
# State: Andhra Pradesh
# Current Condition: Sunny
# Country: India
# Temperature: 36.0
# Wind Speed: 4.0
# Wind Direction: E
# Humidity: 25
# feels: 35.5
