# %%
from selenium import webdriver
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
from webdriver_manager.chrome import ChromeDriverManager
import pandas as pd

# %%
options=webdriver.ChromeOptions()
driver=webdriver.Chrome(options=options)

# %%
driver.get("https://www.myntra.com/")

# %%
search=driver.find_element(By.XPATH,".//input[@class='desktop-searchBar']")

# %%
search.send_keys('smart watches')

# %%
search.send_keys(Keys.ENTER)

# %%
brand=driver.find_elements(By.XPATH,".//h3[@class='product-brand']")
brands=[i.text for i in brand]
print(brands)
len(brands)
# Out:
# ['Fire-Boltt', 'pebble', 'pebble', 'NOISE', 'boAt', 'pebble', 'Fire-Boltt', 'CMF by Nothing', 'Fire-Boltt', 'Fire-Boltt', 'pebble', 'pebble', 'boAt', 'Fire-Boltt', 'NOISE', 'boAt', 'NOISE', 'pebble', 'Fire-Boltt', 'pebble', 'boAt', 'pebble', 'Fire-Boltt', 'boAt', 'pebble', 'Fire-Boltt', 'NOISE', 'Fire-Boltt', 'NOISE', 'Realme', 'NOISE', 'Fire-Boltt', 'boAt', 'Fastrack', 'boAt', 'NOISE', 'Fire-Boltt', 'boAt', 'NOISE', 'Fire-Boltt', 'NOISE', 'Fire-Boltt', 'NOISE', 'Fire-Boltt', 'boAt', 'Timex', 'NOISE', 'Fire-Boltt', 'Cultsport', 'CMF by Nothing']
# 50

# %%
desc=driver.find_elements(By.XPATH,".//h4[@class='product-product']")
descs=[i.text for i in desc]
print(descs)
len(descs)
# Out:
# ['Hurricane Smartwatch', 'Celia 1.32" Display SmartWatch', 'Women 1.27" Smart Watch', 'Fit Posh Smartwatch', 'Unisex Wave Genesis Smartwatch', 'Celia 1.32" Display SmartWatch', 'Supernova Bluetooth SmartWatch', 'Watch Pro', 'Rock AMOLED Display Smartwatch', 'Starlight Bluetooth Smartwatch', 'Cosmos Ultra 1.91" BT Calling Smartwatch', 'Women 1.27" Smart Watch', 'Ultima Prism Smart Watch', 'Cobra AMOLED Smart Watch', 'Fit Posh Smartwatch', 'Lunar Tigon Smartwatch', 'Mettle EliteEdition Smartwatch', 'Hive 1.39" Display Smart Watch', 'Hulk 1.78 inch Smartwatch', 'Pepe Jeans Edition Smartwatch', 'Unisex Ultima Prism Smartwatch', 'Cosmos Quest Smartwatch', 'Eclipse Luxe 1.43" Amoled', 'Lunar Fit Smart Watch', 'Cosmos Ultra 1.91" BT Calling Smartwatch', 'Aura BT Calling Smartwatch', 'ColorFit Icon 2 Smartwatch', 'Visionary TWS Smartwatch', 'Fit Posh Smartwatch', 'TechLife Watch S100', 'ColorFit Icon 2 Smartwatch', 'Eclipse Luxe 1.43" Amoled', 'Storm Plus AMOLED Smart Watch', 'Z1 with HD Display Smartwatch', 'Lunar Fit Smart Watch', 'ColorFit Pro 5 Smartwatch', 'Sphere Rugged Smartwatch', 'Unisex Wave Genesis Smartwatch', 'Fit Posh Smartwatch', 'Avalanche Luxury Smart Watch', 'ColorFit Pro 5 Smartwatch', 'Hulk 1.78 inch Smartwatch', 'Evolve 3 Smartwatch', 'Hurricane Smartwatch', 'Lunar Mirage Smartwatch', 'iConnect Gen+ Smart Watch', 'ColorFit Pro 5 Smartwatch', 'Crusader Amoled 1.43BT Calling', 'Ace X Luxe 1.96" Smart Watches', 'Watch Pro']
# 50

# %%
df=pd.DataFrame(columns=["Brand","Desc","Price"])
df
# Out:
# Empty DataFrame
# Columns: [Brand, Desc, Price]
# Index: []

# %%
df['Brand']=brands
df['Desc']=descs
df['Price']=prices

# %%
df.to_csv("smart watches.csv")
df
# Out:
#              Brand                                      Desc  \
# 0       Fire-Boltt                      Hurricane Smartwatch
# 1           pebble            Celia 1.32" Display SmartWatch
# 2           pebble                   Women 1.27" Smart Watch
# 3            NOISE                       Fit Posh Smartwatch
# 4             boAt            Unisex Wave Genesis Smartwatch
# 5           pebble            Celia 1.32" Display SmartWatch
# 6       Fire-Boltt            Supernova Bluetooth SmartWatch
# 7   CMF by Nothing                                 Watch Pro
# 8       Fire-Boltt            Rock AMOLED Display Smartwatch
# 9       Fire-Boltt            Starlight Bluetooth Smartwatch
# 10          pebble  Cosmos Ultra 1.91" BT Calling Smartwatch
# 11          pebble                   Women 1.27" Smart Watch
# 12            boAt                  Ultima Prism Smart Watch
# 13      Fire-Boltt                  Cobra AMOLED Smart Watch
# 14           NOISE                       Fit Posh Smartwatch
# 15            boAt                    Lunar Tigon Smartwatch
# 16           NOISE            Mettle EliteEdition Smartwatch
# 17          pebble            Hive 1.39" Display Smart Watch
# 18      Fire-Boltt                 Hulk 1.78 inch Smartwatch
# 19          pebble             Pepe Jeans Edition Smartwatch
# 20            boAt            Unisex Ultima Prism Smartwatch
# 21          pebble                   Cosmos Quest Smartwatch
# 22      Fire-Boltt                 Eclipse Luxe 1.43" Amoled
# 23            boAt                     Lunar Fit Smart Watch
# 24          pebble  Cosmos Ultra 1.91" BT Calling Smartwatch
# 25      Fire-Boltt                Aura BT Calling Smartwatch
# 26           NOISE                ColorFit Icon 2 Smartwatch
# 27      Fire-Boltt                  Visionary TWS Smartwatch
# 28           NOISE                       Fit Posh Smartwatch
# 29          Realme                       TechLife Watch S100
# 30           NOISE                ColorFit Icon 2 Smartwatch
# 31      Fire-Boltt                 Eclipse Luxe 1.43" Amoled
# 32            boAt             Storm Plus AMOLED Smart Watch
# 33        Fastrack             Z1 with HD Display Smartwatch
# 34            boAt                     Lunar Fit Smart Watch
# 35           NOISE                 ColorFit Pro 5 Smartwatch
# 36      Fire-Boltt                  Sphere Rugged Smartwatch
# 37            boAt            Unisex Wave Genesis Smartwatch
# 38           NOISE                       Fit Posh Smartwatch
# 39      Fire-Boltt              Avalanche Luxury Smart Watch
# 40           NOISE                 ColorFit Pro 5 Smartwatch
# 41      Fire-Boltt                 Hulk 1.78 inch Smartwatch
# 42           NOISE                       Evolve 3 Smartwatch
# 43      Fire-Boltt                      Hurricane Smartwatch
# 44            boAt                   Lunar Mirage Smartwatch
# 45           Timex                 iConnect Gen+ Smart Watch
# 46           NOISE                 ColorFit Pro 5 Smartwatch
# 47      Fire-Boltt            Crusader Amoled 1.43BT Calling
# 48       Cultsport            Ace X Luxe 1.96" Smart Watches
# 49  CMF by Nothing                                 Watch Pro
#
#                                Price
# 0     Rs. 1700Rs. 8999(Rs. 7299 OFF)
