# %%
import requests

url = "https://myallies-breaking-news-v1.p.rapidapi.com/GetCompanyDetailsBySymbol"

querystring = {"symbol":"twtr"}

headers = {
	"X-RapidAPI-Key": "e8651f6c66msha2d6d69ec13a24dp189ecajsnfdee1667083a",
	"X-RapidAPI-Host": "myallies-breaking-news-v1.p.rapidapi.com"
}

response = requests.get(url, headers=headers, params=querystring)

print(response.json())
# Out:
# {'messages': 'The API is unreachable, please contact the API provider', 'info': 'Your Client (working) ---> Gateway (working) ---> API (not working)'}

# %%
import requests

url = "https://sales-tax-calculator.p.rapidapi.com/rates"

payload = {
	"city": "Menlo Park",
	"state": "CA",
	"street": "1 Hacker Way",
	"zip": "94025"
}
headers = {
	"content-type": "application/json",
	"X-RapidAPI-Key": "b193f981acmshad45a0f532b3bacp1afa1ejsnf933977206c6",
	"X-RapidAPI-Host": "sales-tax-calculator.p.rapidapi.com"
}

response = requests.post(url, json=payload, headers=headers)

print(response.json())
# Out:
# {'tax_on_shipping': False, 'tax_rate': 9.375}
